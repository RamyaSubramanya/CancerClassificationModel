# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mp
import seaborn as sb
import sklearn
import xgboost
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_auc_score, roc_curve, auc
from xgboost import XGBClassifier
import tensorflow
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import Callback, EarlyStopping
import os
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Data pre-processing

# %%
def read_and_split():
    """
    Read the data, split the data into Independent and target variables and train, test datasets on 70:30 ratio
    
    Returns: 
        dataframes: independent and target variables split into train and test datasets
        
    """
    data_path = "D:\Data Science\Machine Learning & Deep Learning ANN (Regression & Classification)\Classification Practicals\BreastCancerPrediction\data\Breast_cancer_data.csv"
    print(data_path)
    data = pd.read_csv(data_path)
    X = data.drop(columns='diagnosis')
    y = data['diagnosis']
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)
    print("Data has been split into train and test")
    
    return X_train, X_test, y_train, y_test

# %% [markdown]
# Logistic Regression, Random Forest and Gradient Boosting models

# %%
def model_and_evaluate(model_name):
    """
    Build model and evaluate the model against the error metrics

    Args:
        model_name (str): Runs the algorithm based on the model name
    
    Returns:
        prints the accuracy of the model
    """
    X_train, X_test, y_train, y_test = read_and_split()

    # print("Data has been received.")
    
    #choose the model (LogisticRegression, RandomForest, GradientBoosting)
    if model_name=='LogisticRegression':
        model = LogisticRegression()
    elif model_name=='RandomForest':
        model = RandomForestClassifier()
    elif model_name=='GradientBoosting':
        model = GradientBoostingClassifier()
            
    #fit the model on train data
    model.fit(X_train, y_train)

    #predictions on test data 
    predictions = model.predict(X_test)
    print("Predictions have been made.")
    
    #check performance of the model
    accuracy = round(accuracy_score(y_test, predictions),2)*100
    confusion_matrix_report = confusion_matrix(y_test, predictions)
    print("Evaluation metrics:")
    print(f'Accuracy:{accuracy}%')
    print(f'Confusion matrix:{confusion_matrix_report}')
    return

# %%
model_and_evaluate(model_name='RandomForest')
# Out:
# D:\Data Science\Machine Learning & Deep Learning ANN (Regression & Classification)\Classification Practicals\BreastCancerPrediction\data\Breast_cancer_data.csv
# Data has been split into train and test
# Predictions have been made.
# Evaluation metrics:
# Accuracy:96.0%
# Confusion matrix:[[ 62   1]
#  [  5 103]]

# %% [markdown]
# Neural Network model

# %%
def neural_network_model(units, learning_rate, epochs):
    """
    Build model and evaluate the model against the error metrics

    Args:
        units (int): number of neurons to be built
        learning_rate (float): controls how much to change the model to minimise the error
        epochs (int): the number of times the algorithm sees and processes the entire training dataset during the learning process 
        
    Returns:
       prints the accuracy of the model

    """
    X_train, X_test, y_train, y_test = read_and_split()
    
    model = Sequential()
    model.add(Dense(units=units, activation='sigmoid'))
    model.add(Dense(units=1))
    
    model.compile(optimizer=Adam(learning_rate=learning_rate), loss='binary_crossentropy', metrics=['accuracy'])
    
    model.fit(x=X_train, y=y_train, batch_size=1, epochs=epochs, callbacks=EarlyStopping(monitor='val_accuracy', patience=15, mode='max'),verbose=1)

    probabilities = model.predict(X_test)
    predictions = (probabilities>0.5).astype(int)
    
    #check performance of the model
    accuracy = round(accuracy_score(y_test, predictions),2)*100
    confusion_matrix_report = confusion_matrix(y_test, predictions)
    print("Evaluation metrics:")
    print(f'Accuracy:{accuracy}%')
    print(f'Confusion matrix:{confusion_matrix_report}')
    return

# %%
neural_network_model(units=40, learning_rate=0.05, epochs=60)
# Out:
# Data has been split into train and test
# Epoch 1/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.6157 - loss: 5.8938
# Epoch 2/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6197 - loss: 6.0632
# Epoch 3/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.5849 - loss: 6.6172
# Epoch 4/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6409 - loss: 5.7256
# Epoch 5/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.5817 - loss: 6.6684
# Epoch 6/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6311 - loss: 5.8817
# Epoch 7/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6600 - loss: 5.4203
# Epoch 8/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6284 - loss: 5.9245
# Epoch 9/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6454 - loss: 5.6533
# Epoch 10/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6189 - loss: 6.0764
# Epoch 11/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.5996 - loss: 6.3830
# Epoch 12/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5777 - loss: 6.7323
# Epoch 13/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6610 - loss: 5.4041
# Epoch 14/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.5922 - loss: 6.5012
# Epoch 15/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6196 - loss: 6.0643
# Epoch 16/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6308 - loss: 5.8865
# Epoch 17/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6624 - loss: 5.3820
# Epoch 18/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6265 - loss: 5.9542
# Epoch 19/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6212 - loss: 6.0386
# Epoch 20/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6487 - loss: 5.6012
# Epoch 21/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6382 - loss: 5.7672
# Epoch 22/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6524 - loss: 5.5421
# Epoch 23/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6442 - loss: 5.6731
# Epoch 24/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6439 - loss: 5.6776
# Epoch 25/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6462 - loss: 5.6408
# Epoch 26/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.5844 - loss: 6.6262
# Epoch 27/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6260 - loss: 5.9629
# Epoch 28/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.5925 - loss: 6.4969
# Epoch 29/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.5986 - loss: 6.3989
# Epoch 30/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6482 - loss: 5.6091
# Epoch 31/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.5762 - loss: 6.7566
# Epoch 32/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6136 - loss: 6.1608
# Epoch 33/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6083 - loss: 6.2452
# Epoch 34/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6378 - loss: 5.7746
# Epoch 35/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6467 - loss: 5.6317
# Epoch 36/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6031 - loss: 6.3275
# Epoch 37/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6597 - loss: 5.4247
# Epoch 38/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6349 - loss: 5.8210
# Epoch 39/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6351 - loss: 5.8172
# Epoch 40/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6709 - loss: 5.2461
# Epoch 41/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6487 - loss: 5.5999
# Epoch 42/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.5819 - loss: 6.6648
# Epoch 43/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6818 - loss: 5.0727
# Epoch 44/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6406 - loss: 5.7304
# Epoch 45/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6182 - loss: 6.0861
# Epoch 46/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6295 - loss: 5.9062
# Epoch 47/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6486 - loss: 5.6029
# Epoch 48/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.5929 - loss: 6.4903
# Epoch 49/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6075 - loss: 6.2581
# Epoch 50/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6672 - loss: 5.3049
# Epoch 51/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6279 - loss: 5.9323
# Epoch 52/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6270 - loss: 5.9472
# Epoch 53/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6033 - loss: 6.3236
# Epoch 54/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6034 - loss: 6.3235
# Epoch 55/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6407 - loss: 5.7281
# Epoch 56/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6296 - loss: 5.9049
# Epoch 57/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6048 - loss: 6.2998
# Epoch 58/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6391 - loss: 5.7539
# Epoch 59/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.5615 - loss: 6.9909
# Epoch 60/60
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6291 - loss: 5.9127
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Evaluation metrics:
# Accuracy:63.0%
# Confusion matrix:[[  0  63]
#  [  0 108]]

# %% [markdown]
# Monte Carlo Simulation

# %%
n_simulations = 100
accuracy_list = []

for i in range(n_simulations):
    X, y = read_and_preprocess()
 
    #split the data into 70:30 ratio
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)
    print("Data has been split into train and test")
    
    print(f'Iteration number:{i+1}')    
    #simulate using the best model so far
    model = RandomForestClassifier()
    model.fit(X_train, y_train)
    predictions = model.predict(X_test)
    
    accuracy = round(accuracy_score(y_test, predictions),2)*100
    accuracy_list.append(accuracy)
    print(f'Accuracy:{accuracy}')
print(f'Predictions have been made for {n_simulations}')
print(f'Accuracy list for {n_simulations}:{accuracy_list}') 

#calculate mean and standard deviation of accuracy scores from the monte carlo simulation
mean_accuracy = sum(accuracy_list)/len(accuracy_list)
sd_accuracy = np.std(accuracy_list)
print(f'Mean of accuracy scores:{mean_accuracy} with a standard deviation of {sd_accuracy}')
# Out:
# Data has been split into train and test
# Iteration number:1
# Accuracy:94.0
# Data has been split into train and test
# Iteration number:2
# Accuracy:89.0
# Data has been split into train and test
# Iteration number:3
# Accuracy:94.0
# Data has been split into train and test
# Iteration number:4
# Accuracy:92.0
# Data has been split into train and test
# Iteration number:5
# Accuracy:92.0
# Data has been split into train and test
# Iteration number:6
# Accuracy:92.0
# Data has been split into train and test
# Iteration number:7
# Accuracy:89.0
# Data has been split into train and test
# Iteration number:8
# Accuracy:91.0
# Data has been split into train and test
# Iteration number:9
# Accuracy:96.0
# Data has been split into train and test
# Iteration number:10
# Accuracy:94.0
# Data has been split into train and test
# Iteration number:11
# Accuracy:93.0
# Data has been split into train and test
# Iteration number:12
# Accuracy:89.0
# Data has been split into train and test
# Iteration number:13
# Accuracy:90.0
# Data has been split into train and test
# Iteration number:14
# Accuracy:92.0
# Data has been split into train and test
# Iteration number:15
# Accuracy:91.0
# Data has been split into train and test
# Iteration number:16
# Accuracy:94.0
# Data has been split into train and test
# Iteration number:17
# Accuracy:87.0
# Data has been split into train and test
# Iteration number:18
# Accuracy:92.0
# Data has been split into train and test
# Iteration number:19
# Accuracy:91.0
# Data has been split into train and test
# Iteration number:20
# Accuracy:94.0
# Data has been split into train and test
# Iteration number:21
# Accuracy:91.0
# Data has been split into train and test
# Iteration number:22
# Accuracy:91.0
# Data has been split into train and test
# Iteration number:23
# Accuracy:91.0
# Data has been split into train and test
# Iteration number:24
# Accuracy:92.0
# Data has been split into train and test
# Iteration number:25
# Accuracy:91.0
# Data has been split into train and test
# Iteration number:26
# Accuracy:88.0
# Data has been split into train and test
# Iteration number:27
# Accuracy:94.0
# Data has been split into train and test
# Iteration number:28
# Accuracy:92.0
# Data has been split into train and test
# Iteration number:29
# Accuracy:91.0
# Data has been split into train and test
# Iteration number:30
# Accuracy:91.0
# Data has been split into train and test
# Iteration number:31
# Accuracy:94.0
# Data has been split into train and test
# Iteration number:32
# Accuracy:90.0
# Data has been split into train and test
# Iteration number:33
# Accuracy:91.0
# Data has been split into train and test
# Iteration number:34
# Accuracy:93.0
# Data has been split into train and test
# Iteration number:35
# Accuracy:94.0
# Data has been split into train and test
# Iteration number:36
# Accuracy:95.0
# Data has been split into train and test
# Iteration number:37
# Accuracy:92.0
# Data has been split into train and test
# Iteration number:38
# Accuracy:91.0
# Data has been split into train and test
# Iteration number:39
# Accuracy:90.0
# Data has been split into train and test
# Iteration number:40
# Accuracy:92.0
# Data has been split into train and test
# Iteration number:41
# Accuracy:93.0
# Data has been split into train and test
# Iteration number:42
# Accuracy:94.0
# Data has been split into train and test
# Iteration number:43
# Accuracy:91.0
# Data has been split into train and test
# Iteration number:44
# Accuracy:85.0
# Data has been split into train and test
# Iteration number:45
# Accuracy:90.0
# Data has been split into train and test
# Iteration number:46
# Accuracy:91.0
# Data has been split into train and test
# Iteration number:47
# Accuracy:92.0
# Data has been split into train and test
# Iteration number:48
# Accuracy:93.0
# Data has been split into train and test
# Iteration number:49
# Accuracy:91.0
# Data has been split into train and test
# Iteration number:50
# Accuracy:90.0
# Data has been split into train and test
# Iteration number:51
# Accuracy:92.0
# Data has been split into train and test
# Iteration number:52
# Accuracy:91.0
# Data has been split into train and test
# Iteration number:53
# Accuracy:93.0
# Data has been split into train and test
# Iteration number:54
# Accuracy:95.0
# Data has been split into train and test
# Iteration number:55
# Accuracy:90.0
# Data has been split into train and test
# Iteration number:56
# Accuracy:93.0
# Data has been split into train and test
# Iteration number:57
# Accuracy:91.0
# Data has been split into train and test
# Iteration number:58
# Accuracy:94.0
# Data has been split into train and test
# Iteration number:59
# Accuracy:94.0
# Data has been split into train and test
# Iteration number:60
# Accuracy:89.0
# Data has been split into train and test
# Iteration number:61
# Accuracy:90.0
# Data has been split into train and test
# Iteration number:62
# Accuracy:95.0
# Data has been split into train and test
# Iteration number:63
# Accuracy:89.0
# Data has been split into train and test
# Iteration number:64
# Accuracy:92.0
# Data has been split into train and test
# Iteration number:65
# Accuracy:92.0
# Data has been split into train and test
# Iteration number:66
# Accuracy:92.0
# Data has been split into train and test
# Iteration number:67
# Accuracy:87.0
# Data has been split into train and test
# Iteration number:68
# Accuracy:89.0
# Data has been split into train and test
# Iteration number:69
# Accuracy:91.0
# Data has been split into train and test
# Iteration number:70
# Accuracy:93.0
# Data has been split into train and test
# Iteration number:71
# Accuracy:93.0
# Data has been split into train and test
# Iteration number:72
# Accuracy:94.0
# Data has been split into train and test
# Iteration number:73
# Accuracy:91.0
# Data has been split into train and test
# Iteration number:74
# Accuracy:94.0
# Data has been split into train and test
# Iteration number:75
# Accuracy:89.0
# Data has been split into train and test
# Iteration number:76
# Accuracy:92.0
# Data has been split into train and test
# Iteration number:77
# Accuracy:91.0
# Data has been split into train and test
# Iteration number:78
# Accuracy:92.0
# Data has been split into train and test
# Iteration number:79
# Accuracy:89.0
# Data has been split into train and test
# Iteration number:80
# Accuracy:96.0
# Data has been split into train and test
# Iteration number:81
# Accuracy:91.0
# Data has been split into train and test
# Iteration number:82
# Accuracy:92.0
# Data has been split into train and test
# Iteration number:83
# Accuracy:93.0
# Data has been split into train and test
# Iteration number:84
# Accuracy:89.0
# Data has been split into train and test
# Iteration number:85
# Accuracy:91.0
# Data has been split into train and test
# Iteration number:86
# Accuracy:93.0
# Data has been split into train and test
# Iteration number:87
# Accuracy:93.0
# Data has been split into train and test
# Iteration number:88
# Accuracy:94.0
# Data has been split into train and test
# Iteration number:89
# Accuracy:92.0
# Data has been split into train and test
# Iteration number:90
# Accuracy:91.0
# Data has been split into train and test
# Iteration number:91
# Accuracy:91.0
# Data has been split into train and test
# Iteration number:92
# Accuracy:93.0
# Data has been split into train and test
# Iteration number:93
# Accuracy:88.0
# Data has been split into train and test
# Iteration number:94
# Accuracy:94.0
# Data has been split into train and test
# Iteration number:95
# Accuracy:94.0
# Data has been split into train and test
# Iteration number:96
# Accuracy:92.0
# Data has been split into train and test
# Iteration number:97
# Accuracy:91.0
# Data has been split into train and test
# Iteration number:98
# Accuracy:94.0
# Data has been split into train and test
# Iteration number:99
# Accuracy:91.0
# Data has been split into train and test
# Iteration number:100
# Accuracy:89.0
# Predictions have been made for 100
# Accuracy list for 100:[94.0, 89.0, 94.0, 92.0, 92.0, 92.0, 89.0, 91.0, 96.0, 94.0, 93.0, 89.0, 90.0, 92.0, 91.0, 94.0, 87.0, 92.0, 91.0, 94.0, 91.0, 91.0, 91.0, 92.0, 91.0, 88.0, 94.0, 92.0, 91.0, 91.0, 94.0, 90.0, 91.0, 93.0, 94.0, 95.0, 92.0, 91.0, 90.0, 92.0, 93.0, 94.0, 91.0, 85.0, 90.0, 91.0, 92.0, 93.0, 91.0, 90.0, 92.0, 91.0, 93.0, 95.0, 90.0, 93.0, 91.0, 94.0, 94.0, 89.0, 90.0, 95.0, 89.0, 92.0, 92.0, 92.0, 87.0, 89.0, 91.0, 93.0, 93.0, 94.0, 91.0, 94.0, 89.0, 92.0, 91.0, 92.0, 89.0, 96.0, 91.0, 92.0, 93.0, 89.0, 91.0, 93.0, 93.0, 94.0, 92.0, 91.0, 91.0, 93.0, 88.0, 94.0, 94.0, 92.0, 91.0, 94.0, 91.0, 89.0]
# Mean of accuracy scores:91.69 with a standard deviation of 2.0084571192833565
